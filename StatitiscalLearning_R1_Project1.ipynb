# %% [markdown]
# # Assignment 1 pgp- AIML

# %%
#Read data from csv ---

import pandas as pd 
df = pd.read_csv("Laliga.csv")

#set row 0 as labels
df.columns = df.iloc[0]

#drop existing row 0 
df = df.drop(df.index[0])

#set index for the data 
df = df.set_index(df.columns[0])

#drop the row 
df.tail(10)
# Out:
# 0                Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 52         Real Union       4     56          72       21         14
# 53         AD Almeria       2     52          68       17         18
# 54             Europa       3     42          54       18          6
# 55             Lleida       2     40          68       13         14
# 56            Leganes       1     35          38        8         11
# 57              Xerez       1     34          38        8         10
# 58             Condal       1     22          30        7          8
# 59    Atletico Tetuan       1     19          30        7          5
# 60   Cultural Leonesa       1     14          30        5          4
# 61             Girona       1      -           -        -          -
#
# 0   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# 52         37      153          184        -         -     -      -     -
# ...

# %% [markdown]
# Use a new python notebook and read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data. (5 points)

# %%
df = df.replace('-',0)
df
# Out:
# 0                Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 1         Real Madrid      86   4385        2762     1647        552
# 2           Barcelona      86   4262        2762     1581        573
# 3     Atletico Madrid      80   3442        2614     1241        598
# 4            Valencia      82   3386        2664     1187        616
# 5     Athletic Bilbao      86   3368        2762     1209        633
# ..                ...     ...    ...         ...      ...        ...
# 57              Xerez       1     34          38        8         10
# 58             Condal       1     22          30        7          8
# 59    Atletico Tetuan       1     19          30        7          5
# 60   Cultural Leonesa       1     14          30        5          4
# 61             Girona       1      0           0        0          0
#
# 0   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# ...

# %% [markdown]
# # Print all the teams which have started playing between 1930-1980. use “Since/lastApp” column (5 points)

# %%
df.columns
# Out:
# Index(['Team', 'Seasons', 'Points', 'GamesPlayed', 'GamesWon', 'GamesDrawn',
#        'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion', 'Runner-up',
#        'Third', 'Fourth', 'Fifth', 'Sixth', 'T', 'Debut', 'Since/LastApp',
#        'BestPosition'],
#       dtype='object', name=0)

# %%
import numpy as np
df['Since/LastApp'] = df['Since/LastApp'].astype(str).str[:4].astype(int)
df
# Out:
# 0                Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 1         Real Madrid      86   4385        2762     1647        552
# 2           Barcelona      86   4262        2762     1581        573
# 3     Atletico Madrid      80   3442        2614     1241        598
# 4            Valencia      82   3386        2664     1187        616
# 5     Athletic Bilbao      86   3368        2762     1209        633
# ..                ...     ...    ...         ...      ...        ...
# 57              Xerez       1     34          38        8         10
# 58             Condal       1     22          30        7          8
# 59    Atletico Tetuan       1     19          30        7          5
# 60   Cultural Leonesa       1     14          30        5          4
# 61             Girona       1      0           0        0          0
#
# 0   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# ...

# %%
# all the teams which have started playing between 1930-1980.
df_new = df[df['Since/LastApp'].between(1930, 1980)]

df_new
# Out:
# 0                Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 41          Burgos CF       6    168         204       59         50
# 42         Pontevedra       6    150         180       53         44
# 45             Arenas       7    107         130       43         21
# 50           Alcoyano       4     76         108       30         16
# 51               Jaen       3     71          90       29         13
# 52         Real Union       4     56          72       21         14
# 53         AD Almeria       2     52          68       17         18
# 54             Europa       3     42          54       18          6
# 58             Condal       1     22          30        7          8
# 59    Atletico Tetuan       1     19          30        7          5
# 60   Cultural Leonesa       1     14          30        5          4
#
# 0   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# ...

# %% [markdown]
# # Print the list of teams which came Top 5 in terms of points (2.5 points)

# %%
df.dtypes
# Out:
# 0
# Team             object
# Seasons          object
# Points           object
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp     int32
# BestPosition     object
# dtype: object

# %%
#convert datatype of point to integer
df['Points'] = df['Points'].astype(int)
df.dtypes
# Out:
# 0
# Team             object
# Seasons          object
# Points            int32
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp     int32
# BestPosition     object
# dtype: object

# %%
#apply operation sort_values by Points
df2 = df.sort_values('Points',ascending=False)
df2['Team'].head(5)
# Out:
# Pos
# 1        Real Madrid
# 2          Barcelona
# 3    Atletico Madrid
# 4           Valencia
# 5    Athletic Bilbao
# Name: Team, dtype: object

# %% [markdown]
# # Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference. (5 points)
# Goal_diff_count = GoalsFor - GoalsAgainst

# %%
df.head(4)
# Out:
# 0               Team Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 1        Real Madrid      86    4385        2762     1647        552
# 2          Barcelona      86    4262        2762     1581        573
# 3    Atletico Madrid      80    3442        2614     1241        598
# 4           Valencia      82    3386        2664     1187        616
#
# 0   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# 1         563     5947         3140       33        23     8      8     3
# 2         608     5900         3114       25        25    12     12     4
# 3         775     4534         3309       10         8    16      9     7
# 4         861     4398         3469        6         6    10     11    10
#
# 0   Sixth   T    Debut  Since/LastApp BestPosition
# Pos
# 1       4  79     1929           1929            1
# 2       6  83     1929           1929            1
# 3       6  56     1929           2002            1
# ...

# %%
def Goal_diff_count(str1):
    df['GoalDiffCount']= df['GoalsFor'].astype(int)-df['GoalsAgainst'].astype(int)
    df3 = df[['GoalDiffCount','Team']]
    display(df3)
    #display(str1)
    if str1=='minm':
        minm = df3['GoalDiffCount'].min()
        print("minimum",minm)
    elif str1=='maxm':
        maxm = df3['GoalDiffCount'].max()
        print("maximum",maxm)
    else :
        print("invalid input")
    
Goal_diff_count('minm')
#Goal_diff_count('maxm')
#Goal_diff_count('maxmgsa')
# Out:
# 0    GoalDiffCount              Team
# Pos
# 1             2807       Real Madrid
# 2             2786         Barcelona
# 3             1225   Atletico Madrid
# 4              929          Valencia
# 5              931   Athletic Bilbao
# ..             ...               ...
# 57             -28             Xerez
# 58             -20            Condal
# 59             -34   Atletico Tetuan
# 60             -31  Cultural Leonesa
# 61               0            Girona
#
# [61 rows x 2 columns]
# minimum -525

# %% [markdown]
# # Create a new column with the name “Winning Percent” and append it to the data set (5 points)
# Percentage of Winning = (GamesWon / GamesPlayed)*100
#
# If there are any numerical error, replace it with 0%
#
# Print the top 5 teams which have the highest Winning percentage

# %%
df.head(4)
# Out:
# 0               Team Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 1        Real Madrid      86    4385        2762     1647        552
# 2          Barcelona      86    4262        2762     1581        573
# 3    Atletico Madrid      80    3442        2614     1241        598
# 4           Valencia      82    3386        2664     1187        616
#
# 0   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# 1         563     5947         3140       33        23     8      8     3
# 2         608     5900         3114       25        25    12     12     4
# 3         775     4534         3309       10         8    16      9     7
# 4         861     4398         3469        6         6    10     11    10
#
# 0   Sixth   T    Debut  Since/LastApp BestPosition  GoalDiffCount
# Pos
# 1       4  79     1929           1929            1           2807
# 2       6  83     1929           1929            1           2786
# ...

# %%
df.drop('GoalDiffCount',axis=1,inplace=True)

# %%
df.head()
# Out:
# 0               Team Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 1        Real Madrid      86    4385        2762     1647        552
# 2          Barcelona      86    4262        2762     1581        573
# 3    Atletico Madrid      80    3442        2614     1241        598
# 4           Valencia      82    3386        2664     1187        616
# 5    Athletic Bilbao      86    3368        2762     1209        633
#
# 0   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# 1         563     5947         3140       33        23     8      8     3
# 2         608     5900         3114       25        25    12     12     4
# 3         775     4534         3309       10         8    16      9     7
# 4         861     4398         3469        6         6    10     11    10
# 5         920     4631         3700        8         7    10      5     8
#
# 0   Sixth   T    Debut  Since/LastApp BestPosition
# Pos
# ...

# %%
#"Winning Percent” and append it to the data set (5 points) Percentage of Winning = (GamesWon / GamesPlayed)*100
df['Winning Percent'] = (df['GamesWon'].astype(int)/df['GamesPlayed'].astype(int))*100
df = df.replace(np.NaN,0)
#df.fillna(0) --- we may use any of these two methods
df.tail(20)
# Out:
# 0                Team Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 42         Pontevedra       6     150         180       53         44
# 43           Numancia       4     148         152       37         37
# 44              Eibar       3     132         114       35         27
# 45             Arenas       7     107         130       43         21
# 46        Real Burgos       3      96         114       26         44
# 47          Gimnastic       4      91         116       34         16
# 48        Extremadura       2      83          80       20         23
# 49             Merida       2      81          80       19         24
# 50           Alcoyano       4      76         108       30         16
# 51               Jaen       3      71          90       29         13
# 52         Real Union       4      56          72       21         14
# 53         AD Almeria       2      52          68       17         18
# ...

# %%
#Print the top 5 teams which have the highest Winning percentage
df.sort_values('Winning Percent',ascending = False)
df[['Team','Winning Percent']].head(5)
# Out:
# 0               Team  Winning Percent
# Pos
# 1        Real Madrid        59.630702
# 2          Barcelona        57.241130
# 3    Atletico Madrid        47.475134
# 4           Valencia        44.557057
# 5    Athletic Bilbao        43.772629

# %% [markdown]
# Group teams based on their “Best position” and print the sum of their points for all positions (7.5 points)

# %%
df.tail(5)
# Out:
# 0                Team Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 57              Xerez       1      34          38        8         10
# 58             Condal       1      22          30        7          8
# 59    Atletico Tetuan       1      19          30        7          5
# 60   Cultural Leonesa       1      14          30        5          4
# 61             Girona       1       0           0        0          0
#
# 0   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# 57         20       38           66        0         0     0      0     0
# 58         15       37           57        0         0     0      0     0
# 59         18       51           85        0         0     0      0     0
# 60         21       34           65        0         0     0      0     0
# 61          0        0            0        0         0     0      0     0
#
# 0   Sixth  T    Debut  Since/LastApp BestPosition  Winning Percent
# Pos
# ...

# %%
df4= df.groupby('BestPosition').sum()
df4['Points']
# Out:
# BestPosition
# 1     27933
# 10      450
# 11      445
# 12      511
# 14       71
# 15       14
# 16       81
# 17      266
# 19       81
# 2      6904
# 20       34
# 3      5221
# 4      6563
# 5      1884
# 6      2113
# 7      1186
# 8      1134
# 9        96
# Name: Points, dtype: int32

# %%
df4.reset_index(inplace=True)

# %%
df4[['BestPosition','Points']]
# Out:
# 0  BestPosition  Points
# 0             1   27933
# 1            10     450
# 2            11     445
# 3            12     511
# 4            14      71
# 5            15      14
# 6            16      81
# 7            17     266
# 8            19      81
# 9             2    6904
# 10           20      34
# 11            3    5221
# 12            4    6563
# 13            5    1884
# 14            6    2113
# 15            7    1186
# 16            8    1134
# 17            9      96
